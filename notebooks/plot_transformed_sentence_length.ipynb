# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sentence_length = 15
alpha = -1.2
sp = 1
transformed_sentence_length = sp / (sentence_length ** (1 / alpha))

print(f"Transformed sentence length: {transformed_sentence_length}")

wealth = 10
arrest_aversion = 1

expected_punishment_pain = wealth + arrest_aversion * transformed_sentence_length
print(f"Expected punishment pain: {expected_punishment_pain}")

old_expected_punishment_pain = wealth + arrest_aversion * sentence_length
print(f"Old expected punishment pain: {old_expected_punishment_pain}")
# Out:
# Transformed sentence length: 9.55159829209756
# Expected punishment pain: 19.55159829209756
# Old expected punishment pain: 25

# %%
# plot the sentence length
x = np.arange(1, 100)
y = sp / (x ** (1 / alpha))

plt.plot(x, y)
plt.title("Transformed sentence length vs sentence length")
plt.xlabel("Sentence length")
plt.ylabel("Transformed sentence length")
plt.show()

# plot a table of sentence length and transformed sentence length
print("Sentence length | Transformed sentence length")
for i in range(1, 30):
    print(f"{i} | {sp / (i ** (1 / alpha))}")
# Out:
# Sentence length | Transformed sentence length
# 1 | 1.0
# 2 | 1.7817974362806785
# 3 | 2.4980495329668133
# 4 | 3.1748021039363987
# 5 | 3.8236224566586503
# 6 | 4.451018253542414
# 7 | 5.061140184796387
# 8 | 5.656854249492381
# 9 | 6.240251469155713
# 10 | 6.812920690579613
# 11 | 7.37610750163904
# 12 | 7.930812913000377
# 13 | 8.477857782354299
# 14 | 9.017926605927322
# 15 | 9.55159829209756
# 16 | 10.079368399158986
# 17 | 10.601665591490098
# 18 | 11.118864069488387
# 19 | 11.631293127556278
# 20 | 12.139244620058346
# 21 | 12.642978874910185
# 22 | 13.142729436151122
# 23 | 13.638706910080277
# 24 | 14.131102116005774
# 25 | 14.620088691064332
# 26 | 15.10582526175109
# 27 | 15.588457268119898
# 28 | 16.068118507008624
# 29 | 16.54493244605062
